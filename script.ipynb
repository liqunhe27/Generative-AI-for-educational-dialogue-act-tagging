# %%
# import necessary packages
import os
import re
import json
import random
from collections import Counter

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report

# !pip install openai
import openai
from tenacity import retry, stop_after_attempt, wait_random_exponential

OPENAI_API_KEY = ''

# %%
# Load data from googld drive
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/MyDrive/pilot_cima/'
os.chdir(path)
print("path=", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# path= /content/drive/MyDrive/pilot_cima

# %%
# Define utility functions

# Define function to count labels
def count_labels(dataset, key = 'tutorActions'):    
    
    # Extract labels from dataset
    labels = []
    for example in dataset:
        labels += example[key]
        
    # Count label occurrences
    label_counts = Counter(labels)
    
    # Print count for each label
    for label, count in label_counts.items():
        print(label, count)
        
        
# Function to clean predicted labels
def clean_labels(outputs):
    """
    Clean predicted labels.

    Args:
    outputs (list): A list of predicted labels.

    Returns:
    cleaned_labels (list): A list of cleaned labels.
    """
    
    # Define a list of labels
    labels = ['Question', 'Hint', 'Correction', 'Confirmation']

    # Define a special symbol
    special_symbol = '*'

    # Define a regular expression pattern that matches any label in the label list
    label_pattern = '|'.join(labels)

    # Initialise an empty list to store cleaned labels
    cleaned_labels = []

    # Loop through each output and extract the label information
    for output in outputs:
        # Match the label using the regular expression pattern
        match = re.search(label_pattern, output)

        # If there is a match, append the label to the cleaned_labels list
        if match:
            cleaned_labels.append(match.group(0))
        # Otherwise, append the special symbol to the cleaned_labels list
        else:
            cleaned_labels.append(special_symbol)

    return cleaned_labels

# %%
# Load data

# The CIMA dataset is from Stasaski, K., Kao, K., & Hearst, M. A. (2020).\
# CIMA: A Large Open Access Dialogue Dataset for Tutoring. 

with open('cima_raw_data.json', 'r') as f:
    data = json.loads(f.read())
    
    # Use 'prepDataset' database
    data = data['prepDataset'] 
    num = len(data.keys())
    print(data['0'].keys(), num)
    
# Convert Python object to DataFrame
df = pd.DataFrame.from_dict(data).T
# Display DataFrame as table in Notebook
# display(df)
# Out:
# dict_keys(['past_convo', 'img', 'prep', 'engPrep', 'obj', 'engObj', 'color', 'engColor', 'grammarRules', 'studentActions', 'tutorResponses', 'tutorActions', 'tutorKeys']) 1135

# %%
# Data Preparation

def generate_dataset(dataframe, num_prev_sentences=1):
    # Dialogue actions labels
    tutorActions_labels = ['Question', 'Hint', 'Correction', 'Confirmation', 'Other']

    # create an empty list to store the output
    output = []

    # iterate through the dataframe
    for i in range(len(dataframe)):
        # create a dictionary to store each session
        session = {}

        # get the specified number of previous sentences of the conversation
        if num_prev_sentences == 2:
             session['tutor_initiation'] = dataframe['past_convo'][i][-2]
        session['student'] = dataframe['past_convo'][i][-1]

        # iterate through the tutorActions and tutorResponses, select responses with a single encoding
        single_encoding_responses = []
        actions = dataframe['tutorActions'][i]
        for j, action in enumerate(actions):
            # if the response has multiple encodings or is labeled as "Other", skip it
            if action[-1] == 1 or 'Other' in dataframe['tutorResponses'][i][j]:
                continue
            encoding_count = sum(action[:-1])
            if encoding_count == 1:
                single_encoding_responses.append(dataframe['tutorResponses'][i][j])

        # if there are responses with a single encoding, randomly select one
        if len(single_encoding_responses) > 0:
            index = random.randint(0, len(single_encoding_responses)-1)
            response = single_encoding_responses[index]
            actions = dataframe['tutorActions'][i][dataframe['tutorResponses'][i].index(response)]

            # create 'tutorResponses' and corresponding 'tutorActions' labels
            session['tutor_response'] = response
            session['tutorActions'] = [label for j, label in enumerate(tutorActions_labels[:-1]) if actions[j]]

            output.append(session)

    # write the output to a JSON file
    folder_name = "dataset"

    # check if the folder exists, if not create it
    if not os.path.exists(folder_name):
        os.mkdir(folder_name)

    with open(f'./dataset/n{num_prev_sentences}_sentences_output.json', 'w') as f:
        json.dump(output, f)

    print('Example:\n', output[1])
    print('\nNum. of examples:', len(output))
    
    return output

dataset = generate_dataset(df, num_prev_sentences=1)
# Out:
# Example:
#  {'student': "Oh okay! then I'll try e accanto al letto roso.", 'tutor_response': 'Wonderful!', 'tutorActions': ['Confirmation']}
#
# Num. of examples: 1065

# %%
# Data splitting

def split_dataset(data, test_size=10):
    tutorActions_labels = ['Question', 'Hint', 'Correction', 'Confirmation']

    # Split the data into training and test sets
    test_data = []
    train_data = []

    for label in tutorActions_labels:
        count = 0
        for sample in data:
            if label in sample['tutorActions'] and count < test_size:
                test_data.append(sample)
                data.remove(sample)
                count += 1

    # Split the training set into samples
    for sample in data:
        train_data.append([sample])

    # Save the test set to a JSON file
    with open(f'./dataset/test_data_{len(test_data)}.json', 'w') as f:
        json.dump(test_data, f)

    # Save the training set to a JSON file (for further fine-tuning experiment)
    with open(f'./dataset/train_data.json', 'w') as f:
        json.dump(train_data, f)

    # Print an example from the test set and the number of examples it contains
    print('Example:\n', test_data[1])
    print('\nNum. of examples:', len(test_data))
    
    return test_data

test_data = split_dataset(dataset, test_size=20)
# Out:
# Example:
#  {'student': 'ok', 'tutor_response': 'OK. Could you say it with correct words?', 'tutorActions': ['Question']}
#
# Num. of examples: 80

# %%
# Select a model
openai.api_key = OPENAI_API_KEY

@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(20))
def get_completion(messages, model="gpt-3.5-turbo", temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature)
    return response.choices[0].message["content"]


def train_model(test_data, sys_message, prompt_message):
    label_predict = []

    # Extract labels from test data
    label_true = [sample['tutorActions'][0] for sample in test_data]
    
    for i in range(len(test_data)):
        test_data[i]['tutorActions'] = []
        info = test_data[i]
        
        # messages
        prompt = prompt_message + f'```{info}```'
        messages = [
            {'role':'system','content':sys_message},
            {'role':'user','content':prompt}]
        
        # Predict
        predict = get_completion(messages)
        print(i, 'predict = ', predict, 'true = ', label_true[i])

        label_predict.append(predict)
        
    return label_predict

# %%
# Training
sys_message = """
Your role is to classify tutor's response to student attempts. \
Students who seek information are not mistaken and do not assign 'Correction' labels.\
Pay more attention to determine the "hint" label.\
Give the final answer without explanation and punctuation."""

prompt_message = """
You will read the information delimited with triple backticks, perform the following steps:

1. Identify student's utterance and tutor's response.
2. Determine whether the tutor is asking an open-ended question with a \
   question mark ('Question'), agreeing with student's words ('Confirmation'), \
   or none of them ('Other').
3. Unless it's not 'Other', label it accordingly and skip other steps. \
   If it's 'Other', proceed to step 4.
4. Determine whether tutor is answering student questions and providing \
   additional information ('Hint') or is explicitly correcting student's mistake ('Correction').
5. Label it accordingly."""

with open('./dataset/test_data_40.json', 'r') as f:
    test_data = json.loads(f.read())

label_predict = train_model(test_data, sys_message, prompt_message)
temp = label_predict
# Out:
# 0 predict =  - Student's utterance: "So what's the correct answer?"
# - Tutor's response: "Are you sure you have all the words in the right order?"
# - Tutor's action: Other
#
# Label: Other true =  Question
# 1 predict =  - Student's utterance: "blu"
# - Tutor's response: "So what do you think the answer is?"
# - Label: Question true =  Question
# 2 predict =  1. Student's utterance: "OK, thanks. Is it "il gatto e vicino al il cane"?"
# Tutor's response: "close, what color is the dog?"
#
# 2. The tutor is asking an open-ended question with a question mark. Hence, the label is 'Question'.
#
# 3. Label: Question
#
#  true =  Question
# 3 predict =  Student: "what is behind?"
# Tutor: "dietro"
#
# Label: Hint true =  Question
# 4 predict =  1. Student's utterance: "e dentro la rosa"
# Tutor's response: "what is the word for box in italian"
#
# 2. Tutor's response is a 'Question'.
#
# 3. Label: 'Question'
#
#  true =  Question
# 5 predict =  Student: what is red?
# Tutor: Is it rosso or rossi?
# Label: Question true =  Question
# 6 predict =  - Student's utterance: "il coniglio e sotto."
# - Tutor's response: "try one more time"
# - Label: Hint true =  Question
# 7 predict =  - Student's utterance: "The dog is inside of the box."
# - Tutor's response: "Now can you translate that to Italian?"
# - Label: Question true =  Question
# 8 predict =  - Student's utterance: "Thank you, I remember now."
# - Tutor's response: "What do you think the full phrase is?"
# - Label: Question true =  Question
# 9 predict =  Student's utterance: 'pianta'
#
# Tutor's response: 'Okay, now that you have all the words translated, can you put them into a sentence?'
#
# Classification: Question true =  Question
# 10 predict =  1. Student's utterance: "is en vicino next to?"
#    Tutor's response: "The "is next to the" is e accanto al."
# 2. The tutor is providing a correction.
# 3. Label: Correction. true =  Hint
# 11 predict =  1. Student's utterance: "Oh! And I can't remember what 'yellow' is..."
# Tutor's response: "'Yellow' is 'gialla.'"
# 2. The tutor is providing information to the student.
# 3. N/A
# 4. The tutor is answering the student's question and providing additional information.
# 5. Label: Hint true =  Hint
# 12 predict =  Student's utterance: "what is is behind?"
# Tutor's response: "e dietro la"
#
# Label: Hint true =  Hint
# 13 predict =  Student's utterance: "What is yellow box in Italian?"
# Tutor's response: ""Yellow box" is "scatola gialla". Gialla is the feminine form, because the noun it modifies (scatola) is feminine."
#
# Label: Hint true =  Hint
# 14 predict =  1. Student's utterance: "How do you say 'bunny'?"
#    Tutor's response: '"Bunny" is "coniglio" and "red" is "rosso"- rosso is the masculine form, because the noun it modifies (coniglio) is masculine.'
# 2. The tutor is not asking an open-ended question or agreeing with the student's words.
# 3. The tutor's response is labeled as 'Hint' since they are answering the student's question and providing additional information.
# Final label: Hint true =  Hint
# 15 predict =  - Student's utterance: "what is next to?"
# - Tutor's response: "Ok, 'next to' would be 'vicino.'"
# - Tutor's actions: []
#
# The tutor is providing a correction to the student's question.
#
# Label: Correction true =  Hint
# 16 predict =  1. Student's utterance: "OK, thanks. Is it "il gatto e davanti alla scatola rosa"?"
# Tutor's response: "OK, "is in front of the" is "e davanti alla""
# 2. The tutor is answering a question asked by the student. Therefore, the label is 'Hint'.
# 3. N/A
# 4. The tutor is providing additional information to the student's question. Therefore, the label is 'Hint'.
# 5. Hint true =  Hint
# 17 predict =  1. Student's utterance: "Understood. How about "il coniglio e dietro la scatola azul"
# Tutor's response: "OK, "box" is "scatola"
# 2. Confirmation
# 3. Confirmation
#  true =  Hint
# 18 predict =  Student's utterance: "Il cane e di fronte al ... how do I say blue?"
# Tutor's response: "Okay, I'll give you a hint. "blue" is "blu""
#
# Label: Hint true =  Hint
# 19 predict =  - Student's utterance: "Okay. What is the word for bed again?"
# - Tutor's response: "The word for bed is letto."
# - Label: Hint true =  Hint
# 20 predict =  1. Student's utterance: "e accanto al coniglio amarillo"
# Tutor's response: "Hmm... "yellow" is "giallo""
#
# 2. Tutor's response is a 'Correction'.
#
# 3. Label: 'Correction'
#
# Final output: Correction true =  Correction
# 21 predict =  1. Student's utterance: "e di fronte al conigli viola"
# Tutor's response: "Almost, "bunny" is "coniglio" so once you change that word, you are correct."
#
# 2. The tutor is providing a correction to the student's mistake.
#
# 3. Label: Correction
#
# Final Label: Correction true =  Correction
# 22 predict =  1. Student's utterance: "e vinceno al planto pinko"
# Tutor's response: "Almost. How do you say "is next to the"?"
# 2. The tutor is asking an open-ended question with a question mark ('Question').
# 3. Label: Question
#  true =  Correction
# 23 predict =  1. Student's utterance: "e vicino alla pianta jaune."
# Tutor's response: "close, can you check your word order?"
#
# 2. Tutor's response is a 'Question'.
#
# 3. Label: 'Question'
#
#  true =  Correction
# 24 predict =  1. Student's utterance: "e dietro la scatola amarillo then is my guess."
# Tutor's response: "No, "amarillo" is Spanish for "yellow." Please try again, using the Italian word for "yellow.""
# 2. The tutor is correcting the student's mistake.
# 3. It's a 'Correction' label.
# 4. It's a 'Correction' label.
#
# Final label: Correction true =  Correction
# 25 predict =  1. Student's utterance: "ok, did I get it correct or should I have done something different?"
# Tutor's response: "No, remember that the adjective follows the noun. Please try again."
#
# 2. The tutor is asking a closed-ended question and providing corrective feedback.
#
# 3. Label: Correction. true =  Correction
# 26 predict =  1. Student's utterance: "Is it e dietro la scatola giala?"
# Tutor's response: "Almost. The last word should be spelled 'gialla'."
# 2. The tutor is providing a correction.
# 3. Label: Correction. true =  Correction
# 27 predict =  1. Student's utterance: "Ok, is it "la palla e dentro la gialla borsa"?"
# 2. Tutor's response: "Almost, adjectives (such as color words) follow the noun they modify in Italian. Just switch the words "gialla" and "borsa" and then you are correct."
# 3. Label: Correction
#  true =  Correction
# 28 predict =  1. Student's utterance: "Oh, "il gatto e vicino al all'albero verde"?"
# Tutor's response: "Almost.  Remember, the "al" gets squooshed together with the "l\'" of l\'albero, so it's just "e vicinio all\'albero verde.""
# 2. The tutor is providing a correction to the student's mistake.
# 3. N/A
# 4. The tutor is correcting the student's mistake.
# 5. Label: Correction true =  Correction
# 29 predict =  1. Student's utterance: "e vicino alla il botano rojo."
# Tutor's response: "Almost, "plant" is "pianta"."
# 2. The tutor is correcting the student's mistake.
# 3. Label: Correction. true =  Correction
# 30 predict =  1. Student's utterance: "Oh okay! then I'll try e accanto al letto roso."
# Tutor's response: "Wonderful!"
# 2. The tutor's response is not a question and does not agree with the student's words.
# 3. Label: Confirmation. true =  Confirmation
# 31 predict =  1. Student's utterance: "How do you say dog?"
# Tutor's response: "That is given, please try to fill in the rest of the sentence."
#
# 2. The tutor is not asking an open-ended question and is not agreeing with the student's words.
#
# 3. Label: Hint
#
# Final Label: Hint true =  Confirmation
# 32 predict =  Student: "e di fronte alla scatola rosa"
# Tutor: "correct"
# Label: None (no action required as the tutor is simply confirming that the student's response is correct) true =  Confirmation
# 33 predict =  1. Student's utterance: "Yes I remember."
# Tutor's response: "Good! The word for "dog" is given; it's "cane.""
# 2. The tutor is confirming the student's words.
# 3. Label: Confirmation. true =  Confirmation
# 34 predict =  Student: "la borsa e di dietro la scatola verde"
# Tutor: "Correct!"
# Label: Other true =  Confirmation
# 35 predict =  1. Student's utterance: "il gatto e vicino all'abero blu."
# Tutor's response: "Correct!"
# 2. The tutor is not asking an open-ended question or agreeing with the student's words.
# 3. Label: Correction. true =  Confirmation
# 36 predict =  Student: "e accanto al bunio amarillo"
# Tutor: "ok"
# Label: Other true =  Confirmation
# 37 predict =  Student's utterance: "okay so alla is a contraction of to and the."
# Tutor's response: "Yes, that is correct."
# Tutor's action: None
#
# Label: Confirmation true =  Confirmation
# 38 predict =  Student's utterance: "il coniglio è dietro il gatto giallo"
#
# Tutor's response: "Great! You're right"
#
# Label: Confirmation true =  Confirmation
# 39 predict =  1. Student's utterance: "e sotto il lavolo rosa"
# Tutor's response: "You're so close! Double check your spelling of table, and you're all set!"
#
# 2. None of the above.
#
# 3. Label: Hint
#
# The tutor is providing additional information to help the student correct their mistake.
#
# Final label: Hint true =  Confirmation

# %%
# Load test data from file
with open('/content/drive/MyDrive/pilot_cima/dataset/test_data_40.json', 'r') as f:
    test_data = json.load(f)

# Extract labels from test data
y_true = [sample['tutorActions'][0] for sample in test_data]

# Clean predicted labels
y_predict = clean_labels(temp)

# Remove samples with '*' label from evaluation
y_true_filtered, y_predict_filtered = [], []
for true, pred in zip(y_true, y_predict):
    if not pred.startswith('*'):
        y_true_filtered.append(true)
        y_predict_filtered.append(pred)

# Compute classification report
# target_names = ['Question', 'Hint', 'Correction', 'Confirmation']
print(classification_report(y_true_filtered, y_predict_filtered, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
# Confirmation       0.80      0.57      0.67         7
#   Correction       0.73      0.80      0.76        10
#         Hint       0.64      0.70      0.67        10
#     Question       0.78      0.78      0.78         9
#
#     accuracy                           0.72        36
#    macro avg       0.74      0.71      0.72        36
# weighted avg       0.73      0.72      0.72        36
