# %%
# The Colab environment does not have this library.
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-0.28.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed openai-0.28.1

# %%
# import necessary packages
import os
import re
import json
import random
from collections import Counter

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, cohen_kappa_score

import openai
from tenacity import retry, stop_after_attempt, wait_random_exponential

# %%
# Load data from googld drive
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/MyDrive/pilot_cima/'
os.chdir(path)
print("path=", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# path= /content/drive/MyDrive/pilot_cima

# %%
# Set the API key
with open('openai_key.txt', 'r') as file:
    OPENAI_API_KEY = file.read().strip()

openai.api_key = OPENAI_API_KEY

# using a random seed to ensure reproducibility
random_seed = 27

# %%
# Define utility functions

# Define function to count labels
def count_labels(dataset, key = 'tutorActions'):

    # Extract labels from dataset
    labels = []
    for example in dataset:
        labels += example[key]

    # Count label occurrences
    label_counts = Counter(labels)

    # Print count for each label
    for label, count in label_counts.items():
        print(label, count)


# Function to clean predicted labels - [backward matching]
def clean_labels(outputs):

    # Define a list of labels
    labels = ['Question', 'Hint', 'Correction', 'Confirmation']

    # Define a special symbol
    special_symbol = '*'

    # Define a regular expression pattern that matches any label in the label list
    label_pattern = '|'.join(labels)

    # Initialise an empty list to store cleaned labels
    cleaned_labels = []

    # Loop through each output in the outputs list and extract the label information
    for output in outputs:

        # Find all labels in the output using the regular expression pattern
        matches = re.findall(label_pattern, output)

        # If there are matches, append the last match to the cleaned_labels list
        if matches:
            last_match = matches[-1]
            cleaned_labels.append(last_match)
        # If there are no matches, append the special symbol to the cleaned_labels list
        else:
            cleaned_labels.append(special_symbol)

    return cleaned_labels

# %%
# Load data

# The CIMA dataset is from Stasaski, K., Kao, K., & Hearst, M. A. (2020).\
# CIMA: A Large Open Access Dialogue Dataset for Tutoring.

with open('cima_raw_data.json', 'r') as f:
    data = json.loads(f.read())

    # Use 'prepDataset' database
    data = data['prepDataset']
    num = len(data.keys())
    print(data['0'].keys(), num)

# Convert Python object to DataFrame
df = pd.DataFrame.from_dict(data).T

# Display DataFrame as table in Notebook
display(df)
# Out:
# dict_keys(['past_convo', 'img', 'prep', 'engPrep', 'obj', 'engObj', 'color', 'engColor', 'grammarRules', 'studentActions', 'tutorResponses', 'tutorActions', 'tutorKeys']) 1135
#                                              past_convo  \
# 0     ["Pink" is "rosa". Please try to fill in the b...
# 1     [Please try to fill in the blank in Italian. ,...
# 2     [Please try to fill in the blank in Italian. ,...
# 3     [Please try to fill in the blank in Italian. ,...
# 4     [Please try to fill in the blank in Italian. ,...
# ...                                                 ...
# 1130  [Please try to fill in the blank in Italian. ,...
# 1131  [Please try to fill in the blank in Italian. ,...
# 1132  [Please try to fill in the blank in Italian. ,...
# 1133  [Green is verde. Please try to fill in the bla...
# 1134  [Yellow is gialla. Please try to fill in the b...
#
#                                          img              prep  \
# 0        "pictures/dog_behind_pink_tree.png"          e dietro
# 1         "pictures/plant_next_pink_bed.png"      e accanto al
# 2          "pictures/cat_next_blue_tree.png"          e vicino
# 3       "pictures/cat_next_yellow_bunny.png"      e accanto al
# 4       "pictures/plant_next_yellow_bed.png"      e accanto al
# ...                                      ...               ...
# 1130  "pictures/bunny_front_purple_tree.png"       e di fronte
# 1131        "pictures/cat_on_yellow_bed.png"      e in cima al
# 1132     "pictures/bunny_front_pink_box.png"  e di fronte alla
# 1133   "pictures/plant_inside_green_box.png"       e dentro la
# 1134     "pictures/cat_front_yellow_box.png"  e di fronte alla
#
#                  engPrep         obj engObj   color engColor  \
# 0          is behind the    l'albero   tree    rosa     pink
# 1         is next to the       letto    bed    rosa     pink
# 2         is next to the  all'albero   tree     blu     blue
# 3         is next to the    coniglio  bunny  giallo   yellow
# 4         is next to the       letto    bed  giallo   yellow
# ...                  ...         ...    ...     ...      ...
# 1130  is in front of the  all'albero   tree   viola   purple
# 1131    is on top of the       letto    bed  giallo   yellow
# 1132  is in front of the     scatola    box    rosa     pink
# 1133    is inside of the     scatola    box   verde    green
# 1134  is in front of the     scatola    box  gialla   yellow
#
#                                            grammarRules  \
# 0     [["l' (\"the\") is prepended to the following ...
# 1     [["al (\"to the\", or \"of the\") is used when...
# 2     [["all' (\"to the\" is prepended to the follow...
# 3     [["al (\"to the\", or \"of the\") is used when...
# 4     [["al (\"to the\", or \"of the\") is used when...
# ...                                                 ...
# 1130  [["all' (to the is prepended to the following ...
# 1131  [["al (to the, or of the) is used when the fol...
# 1132  [["alla (to the) is used when the following wo...
# 1133  [["Prepositional phrases separate the two noun...
# 1134  [["alla (to the) is used when the following wo...
#
#                    studentActions  \
# 0     [False, True, False, False]
# 1     [True, False, False, False]
# 2     [False, False, True, False]
# 3     [True, False, False, False]
# 4     [False, False, True, False]
# ...                           ...
# 1130  [True, False, False, False]
# 1131  [False, True, False, False]
# 1132  [False, True, False, False]
# 1133  [False, True, False, False]
# 1134  [True, False, False, False]
#
#                                          tutorResponses  \
# 0     [Look at your order of words again. Adjectives...
# 1     [Wonderful!, Very good - you are almost comple...
# 2     [So close! Look at the word tree and double ch...
# 3     [Well let's look at your last word "amarillo"....
# 4     [The "is next to the" is e accanto al., No, th...
# ...                                                 ...
# 1130  [Not quite.  The word for "tree" is "all'alber...
# 1131  [I will help you with that, "on top of" transl...
# 1132  [OK, we can break this down one by one. In fro...
# 1133   [Inside of is dentro la. Do you know green box?]
# 1134  [Let's break this down. How to you say yellow ...
#
#                                            tutorActions tutorKeys
# 0     [[False, False, False, False, True], [True, Fa...        []
# 1     [[False, False, False, True, False], [False, F...        []
# 2     [[False, False, False, True, False], [True, Fa...        []
# 3     [[True, False, False, False, False], [True, Fa...        []
# 4     [[False, True, False, False, False], [False, F...        []
# ...                                                 ...       ...
# 1130                [[False, True, True, False, False]]        []
# 1131               [[False, True, False, False, False]]        []
# 1132               [[False, True, False, False, False]]        []
# 1133               [[False, True, False, False, False]]        []
# 1134               [[True, False, False, False, False]]        []
#
# [1135 rows x 13 columns]

# %%
# Data Preparation (with two previous turns)

def generate_dataset(dataframe):

    # Dialogue actions labels
    tutorActions_labels = ['Question', 'Hint', 'Correction', 'Confirmation', 'Other']

    # create an empty list to store the output
    output = []

    # iterate through the dataframe
    for i in range(len(dataframe)):
        # create a dictionary to store each session
        session = {}

        # get the specified number of previous sentences of the conversation
        session['tutor_initiation'] = dataframe['past_convo'][i][-2]
        session['student'] = dataframe['past_convo'][i][-1]

        # iterate through the tutorActions and tutorResponses, select responses with a single encoding
        single_encoding_responses = []
        actions = dataframe['tutorActions'][i]

        # if the response has multiple encodings or is labeled as "Other", skip it
        for j, action in enumerate(actions):
            if action[-1] == 1 or 'Other' in dataframe['tutorResponses'][i][j]:
                continue
            encoding_count = sum(action[:-1])
            if encoding_count == 1:
                single_encoding_responses.append(dataframe['tutorResponses'][i][j])

        # if there are responses with a single encoding, randomly select one (since more than one coworks may reply to the same student's utternace)
        if len(single_encoding_responses) > 0:
            index = random.randint(0, len(single_encoding_responses)-1)
            response = single_encoding_responses[index]
            actions = dataframe['tutorActions'][i][dataframe['tutorResponses'][i].index(response)]

            # create 'tutorResponses' and corresponding 'tutorActions' labels
            session['tutor_response'] = response
            session['tutorActions'] = [label for j, label in enumerate(tutorActions_labels[:-1]) if actions[j]]

            output.append(session)

    print('Example:\n', output[1])
    print('\nNum. of examples:', len(output))

    return output

prepared_data = generate_dataset(df)
# Out:
# Example:
#  {'tutor_initiation': 'Okay, I\'ll give you a hint.  "bed" is  "letto"', 'student': "Oh okay! then I'll try e accanto al letto roso.", 'tutor_response': 'Wonderful!', 'tutorActions': ['Confirmation']}
#
# Num. of examples: 1065

# %%
# Sampling
random.seed(random_seed)

# Define a function to sample data
def sample_dataset(data, category_size = 10):

    tutorActions_labels = ['Question', 'Hint', 'Correction', 'Confirmation']

    sampled_data = []

    for label in tutorActions_labels:
        count = 0
        for sample in data:
            if label in sample['tutorActions'] and count < category_size:
                sampled_data.append(sample)
                data.remove(sample)
                count += 1

    # Print an example from the test set and the number of examples it contains
    print('\nNum. of examples:', len(sampled_data))
    print('Example:\n', sampled_data[0])

    return sampled_data

# %%
# Prompts (sys_message)

def get_sys_message(sys_message_num, num_pre_turn):

  variations = ['Identify tutor\'s response.',
                'Identify student\'s utterance and tutor\'s response.',
                'Identify tutor\'s initiation, student\'s utterance, and tutor\'s response.']

  sys_message_dict = {}

  sys_message_dict['1'] = """
  You will be given a snippet of a tutor-student conversation enclosed within triple backticks.
  Your job is to carefully read this information line by line, and then \
provide a tag of the TUTOR_RESPONSE from the following list.
  Choose ONLY ONE best tag from the list of tags provided here.

  - Question
  - Hint
  - Correction
  - Confirmation
  """

  sys_message_dict['2'] = """
  You will be given a snippet of a tutor-student conversation enclosed within triple backticks.
  Your job is to carefully read this information line by line, and then \
provide a tag of the TUTOR_RESPONSE from the following list.
  After the colon, each tag's explanation is attached
  Choose ONLY ONE best tag from the list of tags provided here.

  - Question: The tutor is asking an open-ended question usually with a question mark
  - Hint: The tutor is answering a student's question and/or providing additional information
  - Correction: The tutor is explicitly correcting student's mistake
  - Confirmation: The tutor is agreeing with student's words

  """

  sys_message_dict['3'] = f"""
  You will be given a snippet of a tutor-student conversation enclosed within triple backticks.

  Your job is to perform the following steps:

  1. {variations[num_pre_turn]}
  2. Determine whether the tutor action is 'Question', 'Confirmation', \
or none of them ('Other').
  3. Unless it's NOT 'Other', choose ONLY ONE tag from 'Question' and 'Confirmation' and skip other steps. \
If it's 'Other', proceed to step 4.
  4. Determine whether the tutor action is 'Hint' or 'Correction'.
  5. Choose ONLY ONE tag from 'Hint' and 'Correction'
  """

  sys_message_dict['4'] = f"""
  You will be given a snippet of a tutor-student conversation enclosed within triple backticks.
  Your job is to perform the following steps:

  1. {variations[num_pre_turn]}
  2. Determine whether the tutor is asking an open-ended question usually with a \
question mark ('Question'), agreeing with student's words ('Confirmation'), \
or none of them ('Other').
  3. Unless it's NOT 'Other', choose ONLY ONE tag from 'Question' and 'Confirmation' and skip other steps. \
If it's 'Other', proceed to step 4.
  4. Determine whether tutor is answering a student's question and/or providing \
additional information ('Hint') or is explicitly correcting student's mistake ('Correction').
  5. Choose ONLY ONE tag from 'Hint' and 'Correction'
  """

  sys_message = sys_message_dict[str(sys_message_num)]

  return sys_message

# %%
# from the sample to generate the user message

def get_user_message(sample, num_pre_turn):

  line_keys = ['tutor_initiation', 'student', 'tutor_response']
  user_message = ''

  for key in line_keys[(2-num_pre_turn):]:
    user_message = user_message + f'{key}: {sample[key]} \n'

  # print('user_message is: \n', user_message)

  return user_message

# %%
# Define the function to implement the model

@retry(wait=wait_random_exponential(min=1, max=10), stop=stop_after_attempt(20))

def get_completion(messages, model, temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature)
    return response.choices[0].message["content"]


def implement_model(samples, Model, sys_message_num, num_pre_turn):

    label_predict = []

    # print an example
    print('Example:\n',
          f'sys_message = {get_sys_message(sys_message_num, num_pre_turn)}',
          f'user_message = {get_user_message(samples[0], num_pre_turn)}\n')

    # Imprement the model to machine tag
    for i in range(len(samples)):

        print('\n', f'Processing the {i}-th sample \n')

        sys_message = get_sys_message(sys_message_num, num_pre_turn)
        user_message = get_user_message(samples[i], num_pre_turn)

        messages = [
            {'role':'system','content':sys_message},
            {'role':'user','content':user_message}]

        # Predict
        predict = get_completion(messages, model= Model)

        # Print the conversation and the predicted result
        print('predict = ', predict, '\ntrue = ', label_true[i])

        label_predict.append(predict)

    return label_predict

# %%
# Sampling
CategorySize = 20  # the number of samples in each category
sampled_data = sample_dataset(prepared_data, CategorySize)

# Extracting labels from sampled data
label_true = [sample['tutorActions'][0] for sample in sampled_data]
# Out:
# Num. of examples: 80
# Example:
#  {'tutor_initiation': 'l\' ("the" is prepended to the following word when it begins with a vowel.', 'student': "So what's the correct answer?", 'tutor_response': 'Are you sure you have all the words in the right order?', 'tutorActions': ['Question']}

# %%
# Set variables
Model = "gpt-4" # select a model 'gpt-3.5-turbo', 'gpt-4'
Sys_message_num = 4  # the number of prompts, 1-basic, 2-elaborative, 3-stepwise, 4-combined
Num_pre_turn = 2  # the number of previous sentences to be considered, 0,1,2

# open data
# with open('25_OCT_sample_data.json', 'w') as file:
#    json.dump(sampled_data, file)

# Implementing
label_predict = implement_model(sampled_data, Model, Sys_message_num, Num_pre_turn)
# Out:
# Example:
#  sys_message =
#   You will be given a snippet of a tutor-student conversation enclosed within triple backticks.
#   Your job is to perform the following steps:
#
#   1. Identify tutor's initiation, student's utterance, and tutor's response.
#   2. Determine whether the tutor is asking an open-ended question usually with a question mark ('Question'), agreeing with student's words ('Confirmation'), or none of them ('Other').
#   3. Unless it's NOT 'Other', choose ONLY ONE tag from 'Question' and 'Confirmation' and skip other steps. If it's 'Other', proceed to step 4.
#   4. Determine whether tutor is answering a student's question and/or providing additional information ('Hint') or is explicitly correcting student's mistake ('Correction').
#   5. Choose ONLY ONE tag from 'Hint' and 'Correction'
#    user_message = tutor_initiation: l' ("the" is prepended to the following word when it begins with a vowel.
# student: So what's the correct answer?
# tutor_response: Are you sure you have all the words in the right order?
#
#
#
#  Processing the 0-th sample
#
# predict =  1. Tutor's initiation: "l' ("the" is prepended to the following word when it begins with a vowel."
#    Student's utterance: "So what's the correct answer?"
#    Tutor's response: "Are you sure you have all the words in the right order?"
#
# 2. The tutor is asking an open-ended question.
#
# 3. 'Question'
# true =  Question
#
#  Processing the 1-th sample
#
# predict =  1. Tutor's initiation: Hmm...  "tree" is  "all'albero"
#    Student's utterance: ok
#    Tutor's response: OK. Could you say it with correct words?
# 2. The tutor is asking an open-ended question.
# 3. 'Question'
# 4. Not applicable.
# 5. Not applicable.
# true =  Question
#
#  Processing the 2-th sample
#
# predict =  1. Tutor's initiation: Please try to fill in the blank in Italian.
# 2. Student's utterance: How do you say "is under"?
# 3. Tutor's response: e sotto
#
# The tutor's response is a 'Hint'.
# true =  Question
#
#  Processing the 3-th sample
#
# predict =  The tutor is asking an open-ended question.
# true =  Question
#
#  Processing the 4-th sample
#
# predict =  1. Tutor's initiation: "Hmm...  "is next to the" is "e vicino al""
#    Student's utterance: "OK, thanks. Is it "il gatto e vicino al il cane"?"
#    Tutor's response: "How do you say red?"
#
# 2. The tutor is asking an open-ended question.
#
# 3. 'Question'
# true =  Question
#
#  Processing the 5-th sample
#
# predict =  1. Tutor's initiation: Okay, I'll give you a hint.  "is inside of the" is  "e dentro la"
#    Student's utterance: e dentro la rosa
#    Tutor's response: what is the word for box in italian
# 2. The tutor is asking an open-ended question.
# 3. 'Question'
# true =  Question
#
#  Processing the 6-th sample
#
# predict =  1. Tutor's initiation: Okay, I'll give you a hint.  "is behind the" is "e dietro il"
#    Student's utterance: what is red?
#    Tutor's response: Is it rosso or rossi?
#
# 2. The tutor is asking an open-ended question.
#
# 3. 'Question'
# true =  Question
#
#  Processing the 7-th sample
#
# predict =  1. Tutor's initiation: Okay, I'll give you a hint.  "box" is  "scatola"
#    Student's utterance: Thank you, I remember now.
#    Tutor's response: What do you think the full phrase is?
# 2. The tutor is asking an open-ended question.
# 3. 'Question'
# true =  Question
#
#  Processing the 8-th sample
#
# predict =  1. Tutor's initiation: "Hmm...  "is in front of the" is "e di fronte alla""
#    Student's utterance: "I believe box is scatola right?"
#    Tutor's response: "Correct"
# 2. The tutor is confirming the student's words.
# 3. 'Confirmation'
# 4. Not applicable.
# 5. Not applicable.
# true =  Question
#
#  Processing the 9-th sample
#
# predict =  1. Tutor's initiation: Hmm...  "dog" is  "cane"
#    Student's utterance: il coniglio e dietro giallo cane.
#    Tutor's response: il coniglio e dietro giallo carne
#
# 2. The tutor's response is not a question or a confirmation.
#
# 3. The category is 'Other'.
#
# 4. The tutor is correcting the student's mistake.
#
# 5. The tag is 'Correction'.
# true =  Question
#
#  Processing the 10-th sample
#
# predict =  1. Tutor's initiation: "Pink" is "rosa". Please try to fill in the blank in Italian.
#    Student's utterance: rosa
#    Tutor's response: Good! Do you know the word for bed?
# 2. The tutor is asking an open-ended question.
# 3. 'Question'
# true =  Question
#
#  Processing the 11-th sample
#
# predict =  1. Tutor's initiation: Remember that  "is next to the" is "e vicino alla"
#    Student's utterance: Ok, I will remember.
#    Tutor's response: Can you put the phrase together now in proper order?
# 2. The tutor is asking an open-ended question.
# 3. 'Question'
# true =  Question
#
#  Processing the 12-th sample
#
# predict =  The tutor's initiation is: "Remember that  "is inside of the" is "e dentro la""
# The student's utterance is: "Ok, I will remember that."
# The tutor's response is: "How do you put it together for "is inside of the pink box"?"
#
# The tutor is asking an open-ended question.
# true =  Question
#
#  Processing the 13-th sample
#
# predict =  1. Tutor's initiation: OK,  "table" is  "tavolo"
#    Student's utterance: what is purple?
#    Tutor's response: Purple is "viola."
#
# 2. The tutor's response is not an open-ended question or a confirmation.
#
# 3. The category is 'Other'.
#
# 4. The tutor is answering the student's question.
#
# 5. The tag is 'Hint'.
# true =  Question
#
#  Processing the 14-th sample
#
# predict =  Tutor initiation: 'il ("the") is used for when the following word (tavolo) is masculine.', 'Words in Italian have a gender associated with them (either masculine or feminine), even when the word is an object, concepts, or abstract ideas.'
# Student utterance: I remember learning that
# Tutor response: Good. Try to write the whole sentence now.
#
# The tutor's response is a 'Question'.
# true =  Question
#
#  Processing the 15-th sample
#
# predict =  1. Tutor's initiation: Okay, I'll give you a hint.  "tree" is  "l'albero"
#    Student's utterance: il coniglio e sotto l'albero?
#    Tutor's response: Almost. Do you know the word for purple?
# 2. The tutor is asking an open-ended question.
# 3. 'Question'
# 4. Not applicable.
# 5. Not applicable.
# true =  Question
#
#  Processing the 16-th sample
#
# predict =  1. Tutor's initiation: Please try to fill in the blank in Italian.
#    Student's utterance: I know the word gatto from the instructions and giallo from what you taught me before.
#    Tutor's response: Try to think what the phrase "is behind the" is in Italian.
# 2. The tutor's response is not a question or a confirmation.
# 3. The tutor's response is 'Other'.
# 4. The tutor is providing a hint to the student.
# 5. The tag for the tutor's response is 'Hint'.
# true =  Question
#
#  Processing the 17-th sample
#
# predict =  The tutor is asking an open-ended question. The appropriate tag is 'Question'.
# true =  Question
#
#  Processing the 18-th sample
#
# predict =  1. Tutor's initiation: "Is Next To The" is "e vicino alla". Please try to fill in the blank in Italian.
#    Student's utterance: et proximo il botano rojo.
#    Tutor's response: Il coniglio e vicino alla pianta rossa.
# 2. The tutor's statement is 'Other'.
# 3. The tutor is 'Correcting' the student's mistake.
# true =  Question
#
#  Processing the 19-th sample
#
# predict =  1. Tutor's initiation: al ("to the", or "of the") is used when the following word (tavolo) is masculine and a singular object.  It is a contraction of the words a ("to") and il ("the").
#    Student's utterance: tavolo
#    Tutor's response: You now have all of the words. How would you fill in the blank?
#
# 2. The tutor is asking an open-ended question.
#
# 3. 'Question'
# true =  Question
#
#  Processing the 20-th sample
#
# predict =  1. Tutor's initiation: OK,  "bag" is  "borsa"
#    Student's utterance: Oh! And I can't remember what "yellow" is...
#    Tutor's response: gialla
# 2. The tutor's response is not a question or a confirmation.
# 3. The category is 'Other'.
# 4. The tutor is answering the student's question.
# 5. The tag is 'Hint'.
# true =  Hint
#
#  Processing the 21-th sample
#
# predict =  1. Tutor's initiation: Please try to fill in the blank in Italian.
# 2. Student's utterance: what is is behind?
# 3. Tutor's response: Remember "is behind" is "e dietro."
# 4. The tutor is providing additional information ('Hint').
# true =  Hint
#
#  Processing the 22-th sample
#
# predict =  1. Tutor's initiation: "Is Inside Of The" is "e dentro la". Please try to fill in the blank in Italian.
#    Student's utterance: What is yellow box in Italian?
#    Tutor's response: "Yellow box" is "scatola gialla". Gialla is the feminine form, because the noun it modifies (scatola) is feminine.
# 2. The tutor's response is 'Other'.
# 3. Not applicable.
# 4. The tutor is answering a student's question and providing additional information.
# 5. The tag is 'Hint'.
# true =  Hint
#
#  Processing the 23-th sample
#
# predict =  1. Tutor's initiation: Please try to fill in the blank in Italian.
#    Student's utterance: How do you say "bunny"?
#    Tutor's response: "Bunny" is "coniglio" and "red" is "rosso"- rosso is the masculine form, because the noun it modifies (coniglio) is masculine.
# 2. The tutor's response is 'Other'.
# 3. Not applicable.
# 4. The tutor is answering a student's question and providing additional information.
# 5. The tag for this snippet is 'Hint'.
# true =  Hint
#
#  Processing the 24-th sample
#
# predict =  1. Tutor's initiation: Please try to fill in the blank in Italian.
# 2. Student's utterance: what is next to?
# 3. Tutor's response: Ok, "next to" would be "vicino."
#
# The tutor's response is a 'Hint'.
# true =  Hint
#
#  Processing the 25-th sample
#
# predict =  1. Tutor's initiation: OK,  "is in front of the" is "e davanti alla"
#    Student's utterance: OK, thanks. Is it "il gatto e davanti alla scatola rosa"?
#    Tutor's response: Perfecto!
# 2. The tutor's response is 'Confirmation'.
# 3. 'Confirmation'
# true =  Hint
#
#  Processing the 26-th sample
#
# predict =  1. Tutor's initiation: "Please try to fill in the blank in Italian."
#    Student's utterance: "What is Italian for is behind the?"
#    Tutor's response: ""e dietro la". Do you know how to say blue box?"
#
# 2. The tutor is asking an open-ended question.
#
# 3. 'Question'
# true =  Hint
#
#  Processing the 27-th sample
#
# predict =  1. Tutor's initiation: Hmm...  "box" is  "scatola"
#    Student's utterance: how do I say in front of?
#    Tutor's response: "e di fronte alla" is in front of the
#
# 2. The tutor's response is not a question or a confirmation, so it's 'Other'.
#
# 4. The tutor is answering the student's question, so the tag is 'Hint'.
# true =  Hint
#
#  Processing the 28-th sample
#
# predict =  1. Tutor's initiation: "Blue" is "blu". Please try to fill in the blank in Italian.
#    Student's utterance: Okay. What is the word for bed again?
#    Tutor's response: Bed is called letto. How do you say on top of the?
#
# 2. The tutor is asking an open-ended question.
#
# 3. 'Question'
#
# 4. The tutor is answering a student's question and providing additional information.
#
# 5. 'Hint'
# true =  Hint
#
#  Processing the 29-th sample
#
# predict =  1. Tutor's initiation: Hmm...  "is under the" is "e sotto il"
#    Student's utterance: What is the word for blue?
#    Tutor's response: blu is blue
# 2. The tutor's response is not a question or a confirmation.
# 3. The category is 'Other'.
# 4. The tutor is answering a student's question.
# 5. The tag is 'Hint'.
# true =  Hint
#
#  Processing the 30-th sample
#
# predict =  1. Tutor's initiation: OK,  "box" is  "scatola"
#    Student's utterance: How do you say dog?
#    Tutor's response: "dog" is "cane". It has already been filled in for you.
# 2. The tutor's response is not a question or a confirmation.
# 3. The tag is 'Other'.
# 4. The tutor is answering the student's question and providing additional information.
# 5. The tag is 'Hint'.
# true =  Hint
#
#  Processing the 31-th sample
#
# predict =  1. Tutor's initiation: "Is In Front Of The" is "e di fronte al". Please try to fill in the blank in Italian.
#    Student's utterance: ok, how do you say bunny?
#    Tutor's response: "Bunny" is coniglio.
#
# 2. The tutor's response is 'Other'.
#
# 4. The tutor is answering a student's question and/or providing additional information ('Hint').
#
# 5. The tag is 'Hint'.
# true =  Hint
#
#  Processing the 32-th sample
#
# predict =  1. Tutor's initiation: Please try to fill in the blank in Italian.
# 2. Student's utterance: I don't remember how to say is in front of the in Italian. Any help?
# 3. Tutor's response: OK. In front of is translated as "e di fronte al".
# 4. The tutor is not asking an open-ended question or agreeing with the student's words.
# 5. The tutor is answering a student's question and providing additional information. So, the tag is 'Hint'.
# true =  Hint
#
#  Processing the 33-th sample
#
# predict =  1. Tutor's initiation: OK,  "table" is  "tavolo"
#    Student's utterance: What is the word for is on top of the again?
#    Tutor's response: e in cima al
# 2. The tutor's response is not a question or a confirmation, so it's 'Other'.
# 3. Not applicable.
# 4. The tutor is answering a student's question, so it's a 'Hint'.
# 5. The tag is 'Hint'.
# true =  Hint
#
#  Processing the 34-th sample
#
# predict =  1. Tutor's initiation: "Is In Front Of The" is "e di fronte alla". Please try to fill in the blank in Italian.
#    Student's utterance: What is the word for blue again?
#    Tutor's response: Blue in Italian sounds close to English, can you guess again?
#
# 2. The tutor's response is a 'Question'.
#
# 3. The appropriate tag is 'Question'.
# true =  Hint
#
#  Processing the 35-th sample
#
# predict =  1. Tutor's initiation: Please try to fill in the blank in Italian.
#    Student's utterance: I can't remember the word for "box".
#    Tutor's response: Box is scatola.
# 2. The tutor's response is not a question or a confirmation.
# 3. The category is 'Other'.
# 4. The tutor is providing additional information.
# 5. The tag is 'Hint'.
# true =  Hint
#
#  Processing the 36-th sample
#
# predict =  1. Tutor's initiation: "Please try to fill in the blank in Italian."
#    Student's utterance: "Can you remind me of Italian for "next to"?"
#    Tutor's response: ""Is next to the" is "e vicino al".  Now try it!"
#
# 2. The tutor's response is not asking an open-ended question or agreeing with the student's words.
#
# 3. The category is 'Other'.
#
# 4. The tutor is answering the student's question and providing additional information.
#
# 5. The tag is 'Hint'.
# true =  Hint
#
#  Processing the 37-th sample
#
# predict =  The tags for this snippet are:
# Tutor initiation: Other
# Tutor response: Correction
# true =  Hint
#
#  Processing the 38-th sample
#
# predict =  1. Tutor's initiation: Please try to fill in the blank in Italian.
#    Student's utterance: What is the word for plant in Italian?
#    Tutor's response: Plant is called pianta. How do you say next to?
#
# 2. The tutor is asking an open-ended question.
#
# 3. 'Question'
#
# 4. Not applicable.
#
# 5. Not applicable.
# true =  Hint
#
#  Processing the 39-th sample
#
# predict =  1. Tutor's initiation: Well,  "is next to the" is  "e accanto al"
#    Student's utterance: So what's the word for purple then?
#    Tutor's response: it is viola
# 2. The tutor's response is not a question or a confirmation.
# 3. The category is 'Other'.
# 4. The tutor is answering a student's question.
# 5. The tag is 'Hint'.
# true =  Hint
#
#  Processing the 40-th sample
#
# predict =  1. Tutor's initiation: Hmm...  "bunny" is  "coniglio"
#    Student's utterance: e accanto al coniglio amarillo
#    Tutor's response: Hmm... "yellow" is "giallo"
#
# 2. The tutor's response is not a question or a confirmation.
#
# 3. The tutor's response is a correction.
# true =  Correction
#
#  Processing the 41-th sample
#
# predict =  1. Tutor's initiation: Please try to fill in the blank in Italian.
#    Student's utterance: e di fronte al conigli viola
#    Tutor's response: Almost, "bunny" is "coniglio" so once you change that word, you are correct.
# 2. The tutor's response is not a question or a confirmation.
# 3. The tutor's response is 'Other'.
# 4. The tutor is correcting the student's mistake.
# 5. The tag for this snippet is 'Correction'.
# true =  Correction
#
#  Processing the 42-th sample
#
# predict =  The tags for this snippet are:
# Tutor initiation: Other
# Student utterance: Other
# Tutor response: Other
# true =  Correction
#
#  Processing the 43-th sample
#
# predict =  tutor_initiation: "Is Inside Of The" is "e dentro la". Please try to fill in the blank in Italian.
# student_utterance: Sì, il gatto è dentro la scatola
# tutor_response: Almost. You need to include the word "rossa" after scatola to make the phrase "scatola rossa".
#
# The tutor's strategy is 'Correction'.
# true =  Correction
#
#  Processing the 44-th sample
#
# predict =  1. Tutor's initiation: Please try to fill in the blank in Italian.
# 2. Student's utterance: e vicino alla pianta jaune.
# 3. Tutor's response: close, can you check your word order?
#
# The tutor's response is a 'Correction'.
# true =  Correction
#
#  Processing the 45-th sample
#
# predict =  1. Tutor's initiation: Okay, I'll give you a hint.  "is behind the" is  "e dietro la"
#    Student's utterance: e dietro la scatola amarillo then is my guess.
#    Tutor's response: yellow :  gialla
# 2. The tutor's response is not a question or a confirmation.
# 3. The category is 'Other'.
# 4. The tutor is correcting the student's mistake.
# 5. The tag is 'Correction'.
# true =  Correction
#
#  Processing the 46-th sample
#
# predict =  1. Tutor's initiation: Can you give me your best guess?
#    Student's utterance: il coniglio e sotto.
#    Tutor's response: Close.  You need to say "the blue tree" afterwards.
# 2. The tutor is asking an open-ended question.
# 3. Tag: Question
# 4. Not applicable.
# 5. Not applicable.
# true =  Correction
#
#  Processing the 47-th sample
#
# predict =  1. Tutor's initiation: "giallo is the masculine form, because the noun it modifies (cane) is masculine."
#    Student's utterance: "ok, did I get it correct or should I have done something different?"
#    Tutor's response: "No, remember that the adjective follows the noun. Please try again."
#
# 2. The tutor's response is not asking an open-ended question or agreeing with the student's words.
#
# 3. The tutor's response is 'Other'.
#
# 4. The tutor is explicitly correcting the student's mistake.
#
# 5. The tag for the tutor's response is 'Correction'.
# true =  Correction
#
#  Processing the 48-th sample
#
# predict =  1. Tutor's initiation: Okay, I'll give you a hint.  "yellow" is "gialla"
#    Student's utterance: Is it e dietro la scatola giala?
#    Tutor's response: Almost, "yellow" is spelled "gialla", not "giala" but everything is correct beyond that.
#
# 2. The tutor's response is not a question or a confirmation, so it's 'Other'.
#
# 4. The tutor is correcting the student's mistake.
#
# 5. The appropriate tag is 'Correction'.
# true =  Correction
#
#  Processing the 49-th sample
#
# predict =  1. Tutor's initiation: Remember that  "tree" is  "all'albero"
#    Student's utterance: Oh, "il gatto e vicino al all'albero verde"?
#    Tutor's response: all' is a contraction of al and l'.
# 2. The tutor's response is not a question or a confirmation.
# 3. The tutor's response is 'Other'.
# 4. The tutor is correcting the student's mistake.
# 5. The tag for this snippet is 'Correction'.
# true =  Correction
#
#  Processing the 50-th sample
#
# predict =  Tutor initiation: il ("the") is used for when the following word (tavolo) is masculine.
# Student utterance: ok
# Tutor response: Remember that "table" is "tavolo". Just replace "lavolo" with "tavolo" and it will be correct.
#
# The tutor's response is a 'Correction'.
# true =  Correction
#
#  Processing the 51-th sample
#
# predict =  1. Tutor's initiation: Okay, I'll give you a hint.  "is next to the" is  "e vicino alla"
#    Student's utterance: e vicino alla il botano rojo.
#    Tutor's response: Almost, "plant" is "pianta".
#
# 2. The tutor's statement is not a question or a confirmation, so it is 'Other'.
#
# 4. The tutor is correcting the student's mistake.
#
# 5. The tag for this snippet is 'Correction'.
# true =  Correction
#
#  Processing the 52-th sample
#
# predict =  1. Tutor's initiation: "il ("the") is used for when the following word (cane) is masculine."
#    Student's utterance: "il coniglio e dietro il giallo cane"
#    Tutor's response: "Almost. Adjectives (such as color words) follow the noun they modify in Italian. "il giallo cane" should be "il cane giallo" but the rest is correct."
#
# 2. The tutor's response is not a question or a confirmation.
#
# 3. The tutor's response is 'Other'.
#
# 4. The tutor is explicitly correcting the student's mistake.
#
# 5. The tag for this snippet is 'Correction'.
# true =  Correction
#
#  Processing the 53-th sample
#
# predict =  Tutor's initiation: Please try to fill in the blank in Italian.
# Student's utterance: al dentro scatola viola
# Tutor's response: The phrase "is behind the" is "e dietro la" in Italian.
#
# The tutor's response is a 'Correction'.
# true =  Correction
#
#  Processing the 54-th sample
#
# predict =  tutor_initiation: alla ("to the") is used when the following word (scatola) is feminine and a singular object.  It is a contraction of a ("to") and la ("the"). When the following word begins with a vowel, this is shortened to all' and prepended to the word.
# student_utterance: okay so alla is a contraction of to and the.
# tutor_response: is it, il coniglio e di fronte alla penke scatola
#
# The tutor's strategy is a 'Question'.
# true =  Correction
#
#  Processing the 55-th sample
#
# predict =  1. Tutor's initiation: OK,  "tree" is  "all'albero"
#    Student's utterance: e vicino all'albero purplio
#    Tutor's response: "Viola" is the word for "purple," not "purplio." Please try again.
#
# 2. The tutor's response is not a question or a confirmation.
#
# 3. The tutor's response is a correction of the student's mistake.
#
# 4. The tag for this snippet is 'Correction'.
# true =  Correction
#
#  Processing the 56-th sample
#
# predict =  Tutor's initiation: Okay, I'll give you a hint.  "box" is  "scatola"
# Student's utterance: e davanti alla scatola rosso
# Tutor's response: You were so close! Everything was perfect until you got to the word "red". "Red is "rossa" not "rosso"
#
# The tutor's response is a 'Correction'.
# true =  Correction
#
#  Processing the 57-th sample
#
# predict =  Tutor's initiation: l' ("the") is prepended to the following word when it begins with a vowel
# Student's utterance: Is it "il coniglio e sotto abero l'verde?"
# Tutor's response: That is incorrect. The phrase would be ""il coniglio e sotto l'albero verde" meaning "the bunny is under the green tree". Do you understand?
#
# The tutor is 'Correcting' the student's mistake.
# true =  Correction
#
#  Processing the 58-th sample
#
# predict =  1. Tutor's initiation: Please try to fill in the blank in Italian.
#    Student's utterance: Is blue, azul?
#    Tutor's response: The word for blue is blu, please try the sentence again.
# 2. The tutor's response is not a question or a confirmation.
# 3. The category is 'Other'.
# 4. The tutor is correcting the student's mistake.
# 5. The tag is 'Correction'.
# true =  Correction
#
#  Processing the 59-th sample
#
# predict =  1. Tutor's initiation: Well,  "is next to the" is "e accanto al"
#    Student's utterance: e accanto al scatola rosa is my guess then.
#    Tutor's response: Almost, "al letto" is "bed", so replace "scatola" with "letto" and you are correct.
# 2. The tutor's response is not a question or a confirmation.
# 3. The tag is 'Other'.
# 4. The tutor is correcting the student's mistake.
# 5. The tag is 'Correction'.
# true =  Correction
#
#  Processing the 60-th sample
#
# predict =  Tutor's initiation: Okay, I'll give you a hint.  "bed" is  "letto"
# Student's utterance: Oh okay! then I'll try e accanto al letto roso.
# Tutor's response: Wonderful!
#
# The tutor's response is a 'Confirmation'.
# true =  Confirmation
#
#  Processing the 61-th sample
#
# predict =  Tutor's initiation: Hmm...  "is behind the" is  "e dietro il"
# Student's utterance: e dietro il al cane rosa
# Tutor's response: That is correct.
#
# The tutor is confirming the student's answer, so the category is 'Confirmation'.
# true =  Confirmation
#
#  Processing the 62-th sample
#
# predict =  Tutor's initiation: Well,  "is in front of the" is  "e di fronte alla"
# Student's utterance: e di fronte alla scatola rosa
# Tutor's response: correct
#
# The tutor is confirming the student's words ('Confirmation').
# true =  Confirmation
#
#  Processing the 63-th sample
#
# predict =  The tutor is confirming the student's response. So, the appropriate tag is 'Confirmation'.
# true =  Confirmation
#
#  Processing the 64-th sample
#
# predict =  tutor_initiation: OK,  "is next to the" is  "e vicino"
# student_utterance: il gatto e vicino all'abero blu.
# tutor_response: Correct!
#
# The tutor's strategy is: Confirmation
# true =  Confirmation
#
#  Processing the 65-th sample
#
# predict =  tutor_initiation: Please try to fill in the blank in Italian.
# student_utterance: e di fronte alla scatola rojo perhaps?
# tutor_response: correct
#
# The tutor's strategy is: Confirmation
# true =  Confirmation
#
#  Processing the 66-th sample
#
# predict =  The tutor is confirming the student's response. So, the appropriate tag is 'Confirmation'.
# true =  Confirmation
#
#  Processing the 67-th sample
#
# predict =  The tutor is asking an open-ended question.
# true =  Confirmation
#
#  Processing the 68-th sample
#
# predict =  1. Tutor's initiation: Remember that  "table" is  "tavolo"
#    Student's utterance: e sotto il lavolo rosa
#    Tutor's response: You're so close! Double check your spelling of table, and y ou're all set!
# 2. The tutor's response is not a question or a confirmation.
# 3. The category is 'Other'.
# 4. The tutor is correcting the student's mistake.
# 5. The tag is 'Correction'.
# true =  Confirmation
#
#  Processing the 69-th sample
#
# predict =  The tags for this snippet are:
# Tutor initiation: Other
# Tutor response: Other
# true =  Confirmation
#
#  Processing the 70-th sample
#
# predict =  Tutor's initiation: Do you know how to say box?
# Student's utterance: scatola
# Tutor's response: scatola
#
# The tutor is confirming the student's answer. So, the tag is 'Confirmation'.
# true =  Confirmation
#
#  Processing the 71-th sample
#
# predict =  The tutor is confirming the student's words ('Confirmation').
# true =  Confirmation
#
#  Processing the 72-th sample
#
# predict =  1. Tutor's initiation: Okay, I'll give you a hint.  "plant" is  "pianta"
#    Student's utterance: I think yellow is gialla correct?
#    Tutor's response: Yes, that's right!  Because "la pianta" is feminine.  Good!
#
# 2. The tutor is confirming the student's words.
#
# 3. The appropriate tag is 'Confirmation'.
# true =  Confirmation
#
#  Processing the 73-th sample
#
# predict =  1. Tutor's initiation: "Well,  "is inside of the" is "e dentro la""
#    Student's utterance: "Ok! The word for box is "scatola," right?"
#    Tutor's response: "Yes the term for box., scatola is correct."
#
# 2. The tutor is confirming the student's words.
#
# 3. The appropriate tag is 'Confirmation'.
# true =  Confirmation
#
#  Processing the 74-th sample
#
# predict =  The tags for this snippet are:
# Tutor initiation: Other
# Tutor response: Other
# true =  Confirmation
#
#  Processing the 75-th sample
#
# predict =  Tutor's initiation: Do you know how to say the plant?
# Student's utterance: La pianta?
# Tutor's response: Correct!
#
# The tutor is confirming the student's answer, so the category is 'Confirmation'.
# true =  Confirmation
#
#  Processing the 76-th sample
#
# predict =  1. Tutor's initiation: Well,  "is inside of the" is "e dentro la"
#    Student's utterance: is box scatola?
#    Tutor's response: Yes, that's right.
# 2. The tutor is confirming the student's words.
# 3. 'Confirmation'
# true =  Confirmation
#
#  Processing the 77-th sample
#
# predict =  1. Tutor's initiation: Remember that  "is next to the" is  "e vicino"
#    Student's utterance: il gatto e vicino the verde tree
#    Tutor's response: that is correct!
# 2. The tutor is confirming the student's words.
# 3. 'Confirmation'
# true =  Confirmation
#
#  Processing the 78-th sample
#
# predict =  1. Tutor's initiation: Okay, I'll give you a hint.  "red" is  "rossa"
#    Student's utterance: okay then, how about e di fronte all scatola rossa?
#    Tutor's response: Correct!!!
#
# 2. The tutor's response is 'Confirmation'.
# true =  Confirmation
#
#  Processing the 79-th sample
#
# predict =  1. Tutor's initiation: Hmm...  "box" is  "scatola"
#    Student's utterance: What is the word for "green"?
#    Tutor's response: verde
# 2. The tutor's response is not a question or a confirmation.
# 3. The category is 'Other'.
# 4. The tutor is answering the student's question.
# 5. The tag is 'Hint'.
# true =  Confirmation

# %%
# Evaluation

# true labels
y_true = label_true

# Clean predicted labels
y_predict = clean_labels(label_predict)

# Remove samples with '*' label from evaluation
y_true_filtered, y_predict_filtered = [], []
for true, pred in zip(y_true, y_predict):
    if not pred.startswith('*'):
        y_true_filtered.append(true)
        y_predict_filtered.append(pred)

# Compute classification report
classification_rep = classification_report(y_true_filtered, y_predict_filtered)

# Calculate Cohen's Kappa
cohen_kappa = 0
cohen_kappa = cohen_kappa_score(y_true_filtered, y_predict_filtered)

# Print the classification report and Cohen's Kappa
# 1-basic, 2-elaborative, 3-stepwise, 4-combined
print(f'model = {Model}, sys_message_num = {Sys_message_num}, and num_pre_turn = {Num_pre_turn}\n')
print(classification_rep)
print(f"Cohen's Kappa: {cohen_kappa}")
# Out:
# model = gpt-4, sys_message_num = 4, and num_pre_turn = 2
#
#               precision    recall  f1-score   support
#
# Confirmation       0.88      0.88      0.88        17
#   Correction       0.83      0.88      0.86        17
#         Hint       0.79      0.75      0.77        20
#     Question       0.71      0.71      0.71        17
#
#     accuracy                           0.80        71
#    macro avg       0.80      0.81      0.80        71
# weighted avg       0.80      0.80      0.80        71
#
# Cohen's Kappa: 0.7368281705056924
