# %%
# The Colab environment does not have this library.
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)

# %%
# import necessary packages
import os
import re
import json
import random
from collections import Counter

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report


import openai
from tenacity import retry, stop_after_attempt, wait_random_exponential

# %%
# Load data from googld drive
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/MyDrive/pilot_cima/'
os.chdir(path)
print("path=", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# path= /content/drive/MyDrive/pilot_cima

# %%
# Set the API key
with open('openai_key.txt', 'r') as file:
    OPENAI_API_KEY = file.read().strip()

openai.api_key = OPENAI_API_KEY

# %%
# Set variables

random_seed = 27 # using a random seed to ensure reproducibility
num_prev_sentences = 1  # the number of previous sentences to be considered
CategorySize = 10  # the number of samples in each category
Model = "gpt-4" # select a model 'gpt-3.5-turbo', 'gpt-4'

# %%
# Define utility functions

# Define function to count labels
def count_labels(dataset, key = 'tutorActions'):

    # Extract labels from dataset
    labels = []
    for example in dataset:
        labels += example[key]

    # Count label occurrences
    label_counts = Counter(labels)

    # Print count for each label
    for label, count in label_counts.items():
        print(label, count)


# Function to clean predicted labels
def clean_labels(outputs):
    """
    Clean predicted labels.

    Args:
    outputs (list): A list of predicted labels.

    Returns:
    cleaned_labels (list): A list of cleaned labels.
    """

    # Define a list of labels
    labels = ['Question', 'Hint', 'Correction', 'Confirmation']

    # Define a special symbol
    special_symbol = '*'

    # Define a regular expression pattern that matches any label in the label list
    label_pattern = '|'.join(labels)

    # Initialise an empty list to store cleaned labels
    cleaned_labels = []

    # Loop through each output and extract the label information
    for output in outputs:
        # Match the label using the regular expression pattern
        match = re.search(label_pattern, output)

        # If there is a match, append the label to the cleaned_labels list
        if match:
            cleaned_labels.append(match.group(0))
        # Otherwise, append the special symbol to the cleaned_labels list
        else:
            cleaned_labels.append(special_symbol)

    return cleaned_labels

# %%
# Load data

# The CIMA dataset is from Stasaski, K., Kao, K., & Hearst, M. A. (2020).\
# CIMA: A Large Open Access Dialogue Dataset for Tutoring.

with open('cima_raw_data.json', 'r') as f:
    data = json.loads(f.read())

    # Use 'prepDataset' database
    data = data['prepDataset']
    num = len(data.keys())
    print(data['0'].keys(), num)

# Convert Python object to DataFrame
df = pd.DataFrame.from_dict(data).T

# Display DataFrame as table in Notebook
display(df)
# Out:
# dict_keys(['past_convo', 'img', 'prep', 'engPrep', 'obj', 'engObj', 'color', 'engColor', 'grammarRules', 'studentActions', 'tutorResponses', 'tutorActions', 'tutorKeys']) 1135
#                                              past_convo  \
# 0     ["Pink" is "rosa". Please try to fill in the b...
# 1     [Please try to fill in the blank in Italian. ,...
# 2     [Please try to fill in the blank in Italian. ,...
# 3     [Please try to fill in the blank in Italian. ,...
# 4     [Please try to fill in the blank in Italian. ,...
# ...                                                 ...
# 1130  [Please try to fill in the blank in Italian. ,...
# 1131  [Please try to fill in the blank in Italian. ,...
# 1132  [Please try to fill in the blank in Italian. ,...
# 1133  [Green is verde. Please try to fill in the bla...
# 1134  [Yellow is gialla. Please try to fill in the b...
#
#                                          img              prep  \
# 0        "pictures/dog_behind_pink_tree.png"          e dietro
# 1         "pictures/plant_next_pink_bed.png"      e accanto al
# 2          "pictures/cat_next_blue_tree.png"          e vicino
# 3       "pictures/cat_next_yellow_bunny.png"      e accanto al
# 4       "pictures/plant_next_yellow_bed.png"      e accanto al
# ...                                      ...               ...
# 1130  "pictures/bunny_front_purple_tree.png"       e di fronte
# 1131        "pictures/cat_on_yellow_bed.png"      e in cima al
# 1132     "pictures/bunny_front_pink_box.png"  e di fronte alla
# 1133   "pictures/plant_inside_green_box.png"       e dentro la
# 1134     "pictures/cat_front_yellow_box.png"  e di fronte alla
#
#                  engPrep         obj engObj   color engColor  \
# 0          is behind the    l'albero   tree    rosa     pink
# 1         is next to the       letto    bed    rosa     pink
# 2         is next to the  all'albero   tree     blu     blue
# 3         is next to the    coniglio  bunny  giallo   yellow
# 4         is next to the       letto    bed  giallo   yellow
# ...                  ...         ...    ...     ...      ...
# 1130  is in front of the  all'albero   tree   viola   purple
# 1131    is on top of the       letto    bed  giallo   yellow
# 1132  is in front of the     scatola    box    rosa     pink
# 1133    is inside of the     scatola    box   verde    green
# 1134  is in front of the     scatola    box  gialla   yellow
#
#                                            grammarRules  \
# 0     [["l' (\"the\") is prepended to the following ...
# 1     [["al (\"to the\", or \"of the\") is used when...
# 2     [["all' (\"to the\" is prepended to the follow...
# 3     [["al (\"to the\", or \"of the\") is used when...
# 4     [["al (\"to the\", or \"of the\") is used when...
# ...                                                 ...
# 1130  [["all' (to the is prepended to the following ...
# 1131  [["al (to the, or of the) is used when the fol...
# 1132  [["alla (to the) is used when the following wo...
# 1133  [["Prepositional phrases separate the two noun...
# 1134  [["alla (to the) is used when the following wo...
#
#                    studentActions  \
# 0     [False, True, False, False]
# 1     [True, False, False, False]
# 2     [False, False, True, False]
# 3     [True, False, False, False]
# 4     [False, False, True, False]
# ...                           ...
# 1130  [True, False, False, False]
# 1131  [False, True, False, False]
# 1132  [False, True, False, False]
# 1133  [False, True, False, False]
# 1134  [True, False, False, False]
#
#                                          tutorResponses  \
# 0     [Look at your order of words again. Adjectives...
# 1     [Wonderful!, Very good - you are almost comple...
# 2     [So close! Look at the word tree and double ch...
# 3     [Well let's look at your last word "amarillo"....
# 4     [The "is next to the" is e accanto al., No, th...
# ...                                                 ...
# 1130  [Not quite.  The word for "tree" is "all'alber...
# 1131  [I will help you with that, "on top of" transl...
# 1132  [OK, we can break this down one by one. In fro...
# 1133   [Inside of is dentro la. Do you know green box?]
# 1134  [Let's break this down. How to you say yellow ...
#
#                                            tutorActions tutorKeys
# 0     [[False, False, False, False, True], [True, Fa...        []
# 1     [[False, False, False, True, False], [False, F...        []
# 2     [[False, False, False, True, False], [True, Fa...        []
# 3     [[True, False, False, False, False], [True, Fa...        []
# 4     [[False, True, False, False, False], [False, F...        []
# ...                                                 ...       ...
# 1130                [[False, True, True, False, False]]        []
# 1131               [[False, True, False, False, False]]        []
# 1132               [[False, True, False, False, False]]        []
# 1133               [[False, True, False, False, False]]        []
# 1134               [[True, False, False, False, False]]        []
#
# [1135 rows x 13 columns]

# %%
# Data Preparation

def generate_dataset(dataframe, num_prev_sentences):

    # Dialogue actions labels
    tutorActions_labels = ['Question', 'Hint', 'Correction', 'Confirmation', 'Other']

    # create an empty list to store the output
    output = []

    # iterate through the dataframe
    for i in range(len(dataframe)):
        # create a dictionary to store each session
        session = {}

        # get the specified number of previous sentences of the conversation
        if num_prev_sentences == 2:
             session['tutor_initiation'] = dataframe['past_convo'][i][-2]
        session['student'] = dataframe['past_convo'][i][-1]

        # iterate through the tutorActions and tutorResponses, select responses with a single encoding
        single_encoding_responses = []
        actions = dataframe['tutorActions'][i]
        for j, action in enumerate(actions):
            # if the response has multiple encodings or is labeled as "Other", skip it
            if action[-1] == 1 or 'Other' in dataframe['tutorResponses'][i][j]:
                continue
            encoding_count = sum(action[:-1])
            if encoding_count == 1:
                single_encoding_responses.append(dataframe['tutorResponses'][i][j])

        # if there are responses with a single encoding, randomly select one (since more than one coworks may reply to the same student's utternace)
        if len(single_encoding_responses) > 0:
            index = random.randint(0, len(single_encoding_responses)-1)
            response = single_encoding_responses[index]
            actions = dataframe['tutorActions'][i][dataframe['tutorResponses'][i].index(response)]

            # create 'tutorResponses' and corresponding 'tutorActions' labels
            session['tutor_response'] = response
            session['tutorActions'] = [label for j, label in enumerate(tutorActions_labels[:-1]) if actions[j]]

            output.append(session)

    # write the output to a JSON file
    folder_name = "dataset"

    # check if the folder exists, if not create it
    if not os.path.exists(folder_name):
        os.mkdir(folder_name)

    with open(f'./dataset/n{num_prev_sentences}_sentences_output.json', 'w') as f:
        json.dump(output, f)

    print('Example:\n', output[1])
    print('\nNum. of examples:', len(output))

    return output

dataset = generate_dataset(df, num_prev_sentences)
# Out:
# Example:
#  {'student': "Oh okay! then I'll try e accanto al letto roso.", 'tutor_response': 'Wonderful!', 'tutorActions': ['Confirmation']}
#
# Num. of examples: 1065

# %%
# Sampling

random.seed(random_seed)

# Define a function to sample data
def sample_dataset(data, category_size= CategorySize):

    tutorActions_labels = ['Question', 'Hint', 'Correction', 'Confirmation']

    sampled_data = []

    for label in tutorActions_labels:
        count = 0
        for sample in data:
            if label in sample['tutorActions'] and count < category_size:
                sampled_data.append(sample)
                data.remove(sample)
                count += 1

#    # Save the test set to a JSON file
#    with open(f'./dataset/sampled_data_{len(sampled_data)}.json', 'w') as f:
#        json.dump(sampled_data, f)

    # Print an example from the test set and the number of examples it contains
    print('\nNum. of examples:', len(sampled_data))
    print('Example:\n', sampled_data[-1])

    return sampled_data

sampled_data = sample_dataset(dataset, CategorySize)

# Extract labels from sampled data
label_true = [sample['tutorActions'][0] for sample in sampled_data]
# Out:
# Num. of examples: 40
# Example:
#  {'student': 'il coniglio è dietro il gatto giallo', 'tutor_response': "Good that's correct.", 'tutorActions': ['Confirmation']}

# %%
# Define the function to implement the model

# @retry(wait=wait_random_exponential(min=1, max=10), stop=stop_after_attempt(20))

def get_completion(messages, model= Model, temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature)
    return response.choices[0].message["content"]

def implement_model(input_data, sys_message):

    label_predict = []

    # Imprement the model to machine tag
    for i in range(len(input_data)):

        print('\n', f'Processing the {i}-th sample')

        # messages
        input_data[i]['tutorActions'] = []
        input = input_data[i]

        # Format the dictionary input
        formatted_str = ', '.join([f"'{key}': '{value}'" for key, value in input.items() if value])
        user_message = formatted_str

        messages = [
            {'role':'system','content':sys_message},
            {'role':'user','content':user_message}]

        # Predict
        predict = get_completion(messages)

        # Print the conversation and the predicted result
        print(user_message)
        print(i, 'predict = ', predict, 'true = ', label_true[i])

        label_predict.append(predict)

    return label_predict

# %%
# Prompts

sys_message1 = """
You will be given a snippet of a tutor-student conversation enclosed within triple backticks,
Your job is to carefully read this information line by line, and then \
provide a tag of the TUTOR_RESPONSE from the following list.
Choose ONLY ONE best tag from the list of tags provided here.

- Question
- Hint
- Correction
- Confirmation
"""

sys_message2 = """
You will be given a snippet of a tutor-student conversation enclosed within triple backticks,
Your job is to carefully read this information line by line, and then \
provide a tag of the TUTOR_RESPONSE from the following list.
After the colon, each tag's explanation is attached
Choose ONLY ONE best tag from the list of tags provided here.

- Question: The tutor is asking an open-ended question usually with a question mark
- Hint: The tutor is answering a student's question and/or providing additional information
- Correction: The tutor is explicitly correcting student's mistake
- Confirmation: The tutor is agreeing with student's words

"""

sys_message3 ="""
You will be given a snippet of a tutor-student conversation enclosed within triple backticks,

Your job is to perform the following steps:

1. Identify student's utterance and tutor's response.
2. Determine whether the tutor action is 'Question','Confirmation', \
   or none of them ('Other').
3. Unless it's NOT 'Other', choose ONLY ONE tag from 'Question' and 'Confirmation' and skip other steps. \
   If it's 'Other', proceed to step 4.
4. Determine whether the tutor action is 'Hint' or 'Correction'.
5. Choose ONLY ONE tag from 'Hint' and 'Correction'
"""

sys_message4 = """
You will be given a snippet of a tutor-student conversation enclosed within triple backticks,

Your job is to perform the following steps:

1. Identify student's utterance and tutor's response.
2. Determine whether the tutor is asking an open-ended question usually with a \
   question mark ('Question'), agreeing with student's words ('Confirmation'), \
   or none of them ('Other').
3. Unless it's NOT 'Other', choose ONLY ONE tag from 'Question' and 'Confirmation' and skip other steps. \
   If it's 'Other', proceed to step 4.
4. Determine whether tutor is answering a student's question and/or providing \
   additional information ('Hint') or is explicitly correcting student's mistake ('Correction').
5. Choose ONLY ONE tag from 'Hint' and 'Correction'

"""


# Implementing

data = sampled_data
label_predict = implement_model(data, sys_message3)
# Out:
#  Processing the 0-th sample
# 'student': 'So what's the correct answer?', 'tutor_response': 'Are you sure you have all the words in the right order?'
# 0 predict =  1. Student's utterance: 'So what's the correct answer?'
#    Tutor's response: 'Are you sure you have all the words in the right order?'
# 2. The tutor action is 'Question'. true =  Question
#
#  Processing the 1-th sample
# 'student': 'ok', 'tutor_response': 'OK. Could you say it with correct words?'
# 1 predict =  1. Student's utterance: 'ok'
#    Tutor's response: 'OK. Could you say it with correct words?'
#
# 2. The tutor action is: 'Question' true =  Question
#
#  Processing the 2-th sample
# 'student': 'OK, thanks. Is it "il gatto e vicino al il cane"?', 'tutor_response': 'How do you say red?'
# 2 predict =  1. Student's utterance: 'OK, thanks. Is it "il gatto e vicino al il cane"?'
#    Tutor's response: 'How do you say red?'
#
# 2. The tutor action is 'Question'. true =  Question
#
#  Processing the 3-th sample
# 'student': 'e dentro la rosa', 'tutor_response': 'what is the word for box in italian'
# 3 predict =  Student's utterance: 'e dentro la rosa'
# Tutor's response: 'what is the word for box in italian'
#
# Tutor action: Question true =  Question
#
#  Processing the 4-th sample
# 'student': 'what is red?', 'tutor_response': 'Is it rosso or rossi?'
# 4 predict =  1. Student's utterance: 'what is red?'
#    Tutor's response: 'Is it rosso or rossi?'
#
# 2. The tutor action is 'Question'. true =  Question
#
#  Processing the 5-th sample
# 'student': 'il coniglio e sotto.', 'tutor_response': 'try one more time'
# 5 predict =  1. Student's utterance: 'il coniglio e sotto.'
#    Tutor's response: 'try one more time'
# 2. The tutor action is not a 'Question' or 'Confirmation'.
# 3. Not applicable.
# 4. The tutor action can be considered as a 'Hint'.
# 5. Tag: 'Hint' true =  Question
#
#  Processing the 6-th sample
# 'student': 'The dog is inside of the box.', 'tutor_response': 'Now can you translate that to Italian?'
# 6 predict =  Student's utterance: 'The dog is inside of the box.'
# Tutor's response: 'Now can you translate that to Italian?'
#
# Tutor action: 'Question' true =  Question
#
#  Processing the 7-th sample
# 'student': 'ok', 'tutor_response': 'Can you know put everything together to complete the phrase? '
# 7 predict =  Student's utterance: 'ok'
# Tutor's response: 'Can you know put everything together to complete the phrase?'
#
# Tutor action: 'Question' true =  Question
#
#  Processing the 8-th sample
# 'student': 'I believe box is scatola right?', 'tutor_response': 'Correct'
# 8 predict =  Student's utterance: 'I believe box is scatola right?'
# Tutor's response: 'Correct'
#
# Tutor action: 'Confirmation' true =  Question
#
#  Processing the 9-th sample
# 'student': 'rosa', 'tutor_response': 'Now that you know the color of the bed, do you remember the word for bed?'
# 9 predict =  1. Student's utterance: 'rosa'
#    Tutor's response: 'Now that you know the color of the bed, do you remember the word for bed?'
#
# 2. The tutor action is 'Question'. true =  Question
#
#  Processing the 10-th sample
# 'student': 'How do you say "is under"?', 'tutor_response': 'e sotto il'
# 10 predict =  1. Student's utterance: 'How do you say "is under"?'
#    Tutor's response: 'e sotto il'
# 2. The tutor action is 'Other'.
# 3. Not applicable.
# 4. The tutor action is 'Correction'.
# 5. 'Correction' true =  Hint
#
#  Processing the 11-th sample
# 'student': 'What is the word for "red"?', 'tutor_response': 'e di fronte al'
# 11 predict =  1. Student's utterance: 'What is the word for "red"?'
#    Tutor's response: 'e di fronte al'
# 2. The tutor action is 'Other'.
# 4. The tutor action is neither 'Hint' nor 'Correction'. true =  Hint
#
#  Processing the 12-th sample
# 'student': 'What is the phrase for under?', 'tutor_response': 'Ok, sotto means under. Do you remember what rosa means?'
# 12 predict =  1. Student's utterance: 'What is the phrase for under?'
#    Tutor's response: 'Ok, sotto means under. Do you remember what rosa means?'
#
# 2. The tutor action is 'Question'. true =  Hint
#
#  Processing the 13-th sample
# 'student': 'And how do you say "is next to the"?', 'tutor_response': 'OK, "Is next to the" is "e vicino alla". '
# 13 predict =  1. Student's utterance: 'And how do you say "is next to the"?'
#    Tutor's response: 'OK, "Is next to the" is "e vicino alla". '
#
# 2. The tutor action is not a 'Question' or 'Confirmation'.
#
# 3. The tutor action is 'Other'.
#
# 4. The tutor action is not a 'Hint' or 'Correction'. true =  Hint
#
#  Processing the 14-th sample
# 'student': 'what is next to?', 'tutor_response': 'Ok, "next to" would be "vicino."'
# 14 predict =  1. Student's utterance: 'what is next to?'
#    Tutor's response: 'Ok, "next to" would be "vicino."'
#
# 2. The tutor action is 'Other'.
#
# 4. The tutor action is not 'Hint' or 'Correction'. true =  Hint
#
#  Processing the 15-th sample
# 'student': 'OK, thanks. Is it "il gatto e davanti alla scatola rosa"?', 'tutor_response': 'OK, "is in front of the" is "e davanti alla"'
# 15 predict =  1. Student's utterance: 'OK, thanks. Is it "il gatto e davanti alla scatola rosa"?'
#    Tutor's response: 'OK, "is in front of the" is "e davanti alla"'
#
# 2. The tutor action is 'Correction'.
#
# 5. The tag is 'Correction'. true =  Hint
#
#  Processing the 16-th sample
# 'student': 'What is Italian for is behind the?', 'tutor_response': '"Behind the" in Italian is "e dietro la"'
# 16 predict =  1. Student's utterance: 'What is Italian for is behind the?'
#    Tutor's response: '"Behind the" in Italian is "e dietro la"'
# 2. The tutor action is 'Other'.
# 4. The tutor action is not 'Hint' or 'Correction'. true =  Hint
#
#  Processing the 17-th sample
# 'student': 'how do I say in front of?', 'tutor_response': '"e di fronte alla" is in front of the '
# 17 predict =  1. Student's utterance: 'how do I say in front of?'
#    Tutor's response: '"e di fronte alla" is in front of the '
#
# 2. The tutor action is 'Other'.
#
# 4. The tutor action is 'Correction'. true =  Hint
#
#  Processing the 18-th sample
# 'student': 'Okay. What is the word for bed again?', 'tutor_response': 'The word for bed is letto.'
# 18 predict =  Student's utterance: 'Okay. What is the word for bed again?'
# Tutor's response: 'The word for bed is letto.'
#
# Tutor action: Other
# Tutor action: Correction true =  Hint
#
#  Processing the 19-th sample
# 'student': 'And how do you say yellow?', 'tutor_response': '"gialla" is the word for "yellow"'
# 19 predict =  1. Student's utterance: 'And how do you say yellow?'
#    Tutor's response: '"gialla" is the word for "yellow"'
# 2. The tutor action is 'Other'.
# 4. The tutor action is 'Correction'. true =  Hint
#
#  Processing the 20-th sample
# 'student': 'is en vicino next to?', 'tutor_response': 'No, that's not correct.'
# 20 predict =  1. Student's utterance: 'is en vicino next to?'
#    Tutor's response: 'No, that's not correct.'
# 2. The tutor action is not a 'Question' or 'Confirmation'.
# 3. The action is 'Other'.
# 4. The tutor action is a 'Correction'.
# 5. The tag is 'Correction'. true =  Correction
#
#  Processing the 21-th sample
# 'student': 'l cane e di fronte al blu coniglio', 'tutor_response': 'Almost, remember in Italian adjectives follow the noun they modify.'
# 21 predict =  1. Student's utterance: 'l cane e di fronte al blu coniglio'
#    Tutor's response: 'Almost, remember in Italian adjectives follow the noun they modify.'
# 2. The tutor action is not a 'Question' or 'Confirmation'.
# 3. The tutor action is 'Other'.
# 4. The tutor action is a 'Correction'. true =  Correction
#
#  Processing the 22-th sample
# 'student': 'Understood. How about "il coniglio e dietro la scatola azul"', 'tutor_response': 'Good guess.  But blue is just "blu."'
# 22 predict =  1. Student's utterance: 'Understood. How about "il coniglio e dietro la scatola azul"'
#    Tutor's response: 'Good guess.  But blue is just "blu."'
# 2. The tutor action is not a 'Question' or 'Confirmation'.
# 3. The tutor action is 'Other'.
# 4. The tutor action is a 'Correction'. true =  Correction
#
#  Processing the 23-th sample
# 'student': 'e vinceno al planto pinko', 'tutor_response': 'Almost. How do you say "is next to the"? '
# 23 predict =  1. Student's utterance: 'e vinceno al planto pinko'
#    Tutor's response: 'Almost. How do you say "is next to the"? '
#
# 2. The tutor action is 'Question'. true =  Correction
#
#  Processing the 24-th sample
# 'student': 'e vicino alla pianta jaune.', 'tutor_response': 'close, can you check your word order?'
# 24 predict =  1. Student's utterance: 'e vicino alla pianta jaune.'
#    Tutor's response: 'close, can you check your word order?'
# 2. The tutor action is not a 'Question' or 'Confirmation'.
# 3. Not applicable.
# 4. The tutor action is a 'Hint'.
# 5. The tag is 'Hint'. true =  Correction
#
#  Processing the 25-th sample
# 'student': 'e dietro la scatola amarillo then is my guess.', 'tutor_response': 'No, "amarillo" is Spanish for "yellow." Please try again, using the Italian word for "yellow."'
# 25 predict =  Student's utterance: 'e dietro la scatola amarillo then is my guess.'
# Tutor's response: 'No, "amarillo" is Spanish for "yellow." Please try again, using the Italian word for "yellow."'
#
# The tutor action is 'Correction'. true =  Correction
#
#  Processing the 26-th sample
# 'student': 'what is behind?', 'tutor_response': 'yes can you name the animals as to which animal is behind the cat'
# 26 predict =  1. Student's utterance: 'what is behind?'
#    Tutor's response: 'yes can you name the animals as to which animal is behind the cat'
# 2. The tutor action is 'Question'. true =  Correction
#
#  Processing the 27-th sample
# 'student': 'ok, did I get it correct or should I have done something different?', 'tutor_response': 'No, remember that the adjective follows the noun. Please try again. '
# 27 predict =  1. Student's utterance: 'ok, did I get it correct or should I have done something different?'
#    Tutor's response: 'No, remember that the adjective follows the noun. Please try again. '
#
# 2. The tutor action is not a 'Question' or 'Confirmation'.
#
# 3. The tutor action is 'Other'.
#
# 4. The tutor action is a 'Correction'. true =  Correction
#
#  Processing the 28-th sample
# 'student': 'Is it e dietro la scatola giala?', 'tutor_response': 'Almost, "yellow" is spelled "gialla", not "giala" but everything is correct beyond that. '
# 28 predict =  1. Student's utterance: 'Is it e dietro la scatola giala?'
#    Tutor's response: 'Almost, "yellow" is spelled "gialla", not "giala" but everything is correct beyond that.'
#
# 2. The tutor action is not a 'Question' or 'Confirmation'.
#
# 3. The tutor action is 'Other'.
#
# 4. The tutor action is a 'Correction'. true =  Correction
#
#  Processing the 29-th sample
# 'student': 'Oh, "il gatto e vicino al all'albero verde"?', 'tutor_response': 'all' is a contraction of al and l'.'
# 29 predict =  1. Student's utterance: 'Oh, "il gatto e vicino al all'albero verde"?'
#    Tutor's response: 'all' is a contraction of al and l'.
#
# 2. The tutor action is not a 'Question' or 'Confirmation'.
#
# 3. The tutor action is 'Other'.
#
# 4. The tutor action is a 'Correction'. true =  Correction
#
#  Processing the 30-th sample
# 'student': 'Oh okay! then I'll try e accanto al letto roso.', 'tutor_response': 'Wonderful!'
# 30 predict =  1. Student's utterance: 'Oh okay! then I'll try e accanto al letto roso.'
#    Tutor's response: 'Wonderful!'
# 2. The tutor action is not a 'Question' or 'Confirmation'.
# 3. The action is 'Other'.
# 4. The tutor action is neither a 'Hint' nor a 'Correction'. true =  Confirmation
#
#  Processing the 31-th sample
# 'student': 'e di fronte al conigli viola', 'tutor_response': 'Perfect!'
# 31 predict =  Student's utterance: 'e di fronte al conigli viola'
# Tutor's response: 'Perfect!'
#
# The tutor action is 'Confirmation'. true =  Confirmation
#
#  Processing the 32-th sample
# 'student': 'blu', 'tutor_response': 'correct, the table is blue so blu is correct'
# 32 predict =  1. Student's utterance: 'blu'
#    Tutor's response: 'correct, the table is blue so blu is correct'
# 2. The tutor action is 'Confirmation'. true =  Confirmation
#
#  Processing the 33-th sample
# 'student': 'How do you say dog?', 'tutor_response': 'That is given, please try to fill in the rest of the sentence.'
# 33 predict =  1. Student's utterance: 'How do you say dog?'
#    Tutor's response: 'That is given, please try to fill in the rest of the sentence.'
# 2. The tutor action is not a 'Question' or 'Confirmation'.
# 3. The tutor action is 'Other'.
# 4. The tutor action is a 'Hint'.
# 5. The tag is 'Hint'. true =  Confirmation
#
#  Processing the 34-th sample
# 'student': 'e di fronte alla scatola rosa', 'tutor_response': 'Correct!'
# 34 predict =  Student's utterance: 'e di fronte alla scatola rosa'
# Tutor's response: 'Correct!'
#
# Tutor action: 'Confirmation' true =  Confirmation
#
#  Processing the 35-th sample
# 'student': 'pianta', 'tutor_response': 'That is correct! Now please try to fill in the blank. '
# 35 predict =  Student's utterance: 'pianta'
# Tutor's response: 'That is correct! Now please try to fill in the blank. '
#
# Tutor action: Confirmation true =  Confirmation
#
#  Processing the 36-th sample
# 'student': 'il gatto e vicino all'abero blu.', 'tutor_response': 'Correct!'
# 36 predict =  Student's utterance: 'il gatto e vicino all'abero blu.'
# Tutor's response: 'Correct!'
#
# The tutor action is 'Confirmation'. true =  Confirmation
#
#  Processing the 37-th sample
# 'student': 'e accanto al bunio amarillo', 'tutor_response': 'ok'
# 37 predict =  Student's utterance: 'e accanto al bunio amarillo'
# Tutor's response: 'ok'
#
# The tutor action is 'Confirmation'. true =  Confirmation
#
#  Processing the 38-th sample
# 'student': 'okay so alla is a contraction of to and the.', 'tutor_response': 'Yes, that is correct.'
# 38 predict =  Student's utterance: 'okay so alla is a contraction of to and the.'
# Tutor's response: 'Yes, that is correct.'
#
# Tutor action: Confirmation true =  Confirmation
#
#  Processing the 39-th sample
# 'student': 'il coniglio è dietro il gatto giallo', 'tutor_response': 'Good that's correct.'
# 39 predict =  Student's utterance: 'il coniglio è dietro il gatto giallo'
# Tutor's response: 'Good that's correct.'
#
# The tutor action is 'Confirmation'. true =  Confirmation

# %%
# Load test data from file
# with open('/content/drive/MyDrive/pilot_cima/dataset/test_data_40.json', 'r') as f:
#    test_data = json.load(f)

# Extract labels from test data
y_true = label_true

# Clean predicted labels
y_predict = clean_labels(label_predict)

# Remove samples with '*' label from evaluation
y_true_filtered, y_predict_filtered = [], []
for true, pred in zip(y_true, y_predict):
    if not pred.startswith('*'):
        y_true_filtered.append(true)
        y_predict_filtered.append(pred)

# Compute classification report
print(classification_report(y_true_filtered, y_predict_filtered))
# Out:
#               precision    recall  f1-score   support
#
# Confirmation       0.89      0.80      0.84        10
#   Correction       0.17      0.10      0.12        10
#         Hint       1.00      0.30      0.46        10
#     Question       0.41      0.90      0.56        10
#
#     accuracy                           0.53        40
#    macro avg       0.62      0.53      0.50        40
# weighted avg       0.62      0.53      0.50        40

# %%
gpt_3_result = classification_report(y_true_filtered, y_predict_filtered)

# %%
print(gpt_3_result)
# Out:
#               precision    recall  f1-score   support
#
# Confirmation       0.82      0.90      0.86        10
#   Correction       0.40      0.80      0.53        10
#         Hint       0.33      0.10      0.15        10
#     Question       1.00      0.60      0.75        10
#
#     accuracy                           0.60        40
#    macro avg       0.64      0.60      0.57        40
# weighted avg       0.64      0.60      0.57        40
